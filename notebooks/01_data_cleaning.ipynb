# %%
import pandas as pd
import os
import glob

# %%
# Load all street crime files
street_files = glob.glob('../data/raw/**/*street*.csv', recursive=True)

dfs = []
for file in street_files:
    df = pd.read_csv(file)
    # Extract force name from filename
    df['force'] = os.path.basename(file).split('-')[2]
    dfs.append(df)

street = pd.concat(dfs, ignore_index=True)
print(f"Loaded {len(street):,} rows from {len(street_files)} files")
street.head()
# Out:
# Loaded 470,228 rows from 50 files
#                                             Crime ID    Month  \
# 0  3805030082ced818125d730fd7c0a1c6087320be923ce7...  2023-12
# 1  ecb65a50a49b09cc5378e4f83459050e8e05db315eea08...  2023-12
# 2  49ae18115c1bd911c2a6bc178553681a5800b64b59b7ba...  2023-12
# 3                                                NaN  2023-12
# 4  d2530e8c1f64fb5638533662d9c22e219b2cc4834ae57d...  2023-12
#
#                Reported by             Falls within  Longitude   Latitude  \
# 0  Derbyshire Constabulary  Derbyshire Constabulary  -1.376936  53.098607
# 1  Derbyshire Constabulary  Derbyshire Constabulary  -1.373582  53.099210
# 2  Derbyshire Constabulary  Derbyshire Constabulary  -1.374915  53.103055
# 3  Derbyshire Constabulary  Derbyshire Constabulary  -1.381946  53.101240
# 4  Derbyshire Constabulary  Derbyshire Constabulary  -1.373886  53.099904
#
#                       Location  LSOA code          LSOA name  \
# 0    On or near Mansfield Road  E01019400  Amber Valley 001A
# 1  On or near Catherine Street  E01019400  Amber Valley 001A
# 2  On or near Tavistock Square  E01019400  Amber Valley 001A
# 3      On or near Cedar Avenue  E01019400  Amber Valley 001A
# 4   On or near Catherine Court  E01019400  Amber Valley 001A
#
#                      Crime type  \
# 0                         Drugs
# 1                  Public order
# 2  Violence and sexual offences
# 3         Anti-social behaviour
# 4                   Other theft
#
#                            Last outcome category  Context       force
# 0                       Court result unavailable      NaN  derbyshire
# 1                    Unable to prosecute suspect      NaN  derbyshire
# 2                       Court result unavailable      NaN  derbyshire
# 3                                            NaN      NaN  derbyshire
# 4  Investigation complete; no suspect identified      NaN  derbyshire

# %%
# Drop columns that aren't useful
street = street.drop(columns=['Context', 'Falls within', 'Reported by'], errors='ignore')

# Rename columns to be more code-friendly
street.columns = [c.lower().replace(' ', '_') for c in street.columns]

# Drop rows with no location data
street = street.dropna(subset=['latitude', 'longitude'])

# Convert month to datetime
street['month'] = pd.to_datetime(street['month'])

print(f"Clean dataset: {len(street):,} rows")
print(street.columns.tolist())
street.head()
# Out:
# Clean dataset: 468,342 rows
# ['crime_id', 'month', 'longitude', 'latitude', 'location', 'lsoa_code', 'lsoa_name', 'crime_type', 'last_outcome_category', 'force']
#                                             crime_id      month  longitude  \
# 0  3805030082ced818125d730fd7c0a1c6087320be923ce7... 2023-12-01  -1.376936
# 1  ecb65a50a49b09cc5378e4f83459050e8e05db315eea08... 2023-12-01  -1.373582
# 2  49ae18115c1bd911c2a6bc178553681a5800b64b59b7ba... 2023-12-01  -1.374915
# 3                                                NaN 2023-12-01  -1.381946
# 4  d2530e8c1f64fb5638533662d9c22e219b2cc4834ae57d... 2023-12-01  -1.373886
#
#     latitude                     location  lsoa_code          lsoa_name  \
# 0  53.098607    On or near Mansfield Road  E01019400  Amber Valley 001A
# 1  53.099210  On or near Catherine Street  E01019400  Amber Valley 001A
# 2  53.103055  On or near Tavistock Square  E01019400  Amber Valley 001A
# 3  53.101240      On or near Cedar Avenue  E01019400  Amber Valley 001A
# 4  53.099904   On or near Catherine Court  E01019400  Amber Valley 001A
#
#                      crime_type  \
# 0                         Drugs
# 1                  Public order
# 2  Violence and sexual offences
# 3         Anti-social behaviour
# 4                   Other theft
#
#                            last_outcome_category       force
# 0                       Court result unavailable  derbyshire
# 1                    Unable to prosecute suspect  derbyshire
# 2                       Court result unavailable  derbyshire
# 3                                            NaN  derbyshire
# 4  Investigation complete; no suspect identified  derbyshire

# %%
os.makedirs('../data/processed', exist_ok=True)
street.to_csv('../data/processed/street_clean.csv', index=False)
print("Saved to data/processed/street_clean.csv")
# Out:
# Saved to data/processed/street_clean.csv
